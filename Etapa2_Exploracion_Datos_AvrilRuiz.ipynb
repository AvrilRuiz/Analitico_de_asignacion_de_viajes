# %% [markdown]
# Avril Michelle Ruiz Martínez
#
# A00833018

# %% [markdown]
# # 1) Comprensión y exploración de los datos del negocio:

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt  
import seaborn as sns

# %% [markdown]
# ### Lectura de datos

# %%
df_1 = pd.read_excel("AsignacionViajesITESM.xlsx")

# %%
df_2 = pd.read_excel("SegundaBase.xlsx")

# %% [markdown]
# ### Exploración de ambos df

# %% [markdown]
# df_1 contiene datos de la planta de Guerrero

# %%
df_1.head()
# Out:
#   PLANTAORIGEN        FECHADESPACHO  C_ID_VIAJE           FECHAVIAJE  \
# 0     Guerrero  2022-11-06 23:19:19    47103405  05-11-2022 15:16:00
# 1     Guerrero  2022-11-16 14:58:16    47322566  19-11-2022 10:27:00
# 2     Guerrero  2022-11-18 07:14:21    47358720  18-11-2022 00:20:00
# 3     Guerrero  2022-11-19 07:46:41    47369172  18-11-2022 12:18:00
# 4     Guerrero  2022-11-23 15:13:51    47480917  23-11-2022 23:59:00
#
#     C_CLIENTE   D_CLIENTE  ID_ESTADO      ESTADO D_EMPRESA_TRANSPORTISTA  \
# 0         NaN   CLIENTE58         19  Nuevo León             TRANPORTE68
# 1         NaN  CLIENTE132         19  Nuevo Leon             TRANPORTE68
# 2         NaN   CLIENTE58         19  Nuevo León             TRANPORTE68
# 3         NaN   CLIENTE58         19  Nuevo León             TRANPORTE68
# 4  H000232500  CLIENTE171         19  NUEVO LEÓN             TRANPORTE68
#
#    C_ID_CONDUCTOR  ...           F_FINCARGA       F_PESAJESALIDA  \
# ...

# %%
df_1.shape
# Out:
# (9154, 34)

# %%
x = df_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9154 entries, 0 to 9153
# Data columns (total 34 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   PLANTAORIGEN             9154 non-null   object
#  1   FECHADESPACHO            9154 non-null   object
#  2   C_ID_VIAJE               9154 non-null   int64
#  3   FECHAVIAJE               9154 non-null   object
#  4   C_CLIENTE                4881 non-null   object
#  5   D_CLIENTE                9136 non-null   object
#  6   ID_ESTADO                9154 non-null   int64
#  7   ESTADO                   9154 non-null   object
#  8   D_EMPRESA_TRANSPORTISTA  9154 non-null   object
#  9   C_ID_CONDUCTOR           9154 non-null   int64
#  10  NOM_APE_COND             9153 non-null   object
#  11  TIPO_SERVICIO            9154 non-null   object
#  12  TIPOCAMION               9154 non-null   object
#  13  TIPOTRANSPORTE           9154 non-null   object
# ...

# %% [markdown]
# df_2 contiene datos de la planta de Pesquería

# %%
df_2.head()
# Out:
#   PLANTAORIGEN        FECHADESPACHO  C_ID_VIAJE           FECHAVIAJE  \
# 0    Pesquería  01/10/2022 01:36:16    46227308  30/09/2022 23:59:00
# 1    Pesquería  01/10/2022 05:38:00    46248480  01/10/2022 14:13:00
# 2    Pesquería  01/10/2022 04:04:55    46260526  01/10/2022 23:59:00
# 3    Pesquería  01/10/2022 04:59:28    46252417  30/09/2022 17:44:00
# 4    Pesquería  01/10/2022 01:31:28    46246049  01/10/2022 11:47:00
#
#     C_CLIENTE C_CLIENTE.1  ID_ESTADO           ESTADO D_EMPRESA_TRANSPORTISTA  \
# 0  N000003805   CLIENTE27          2  BAJA CALIFORNIA             TRANPORTE31
# 1  H000030812  CLIENTE198         11       GUANAJUATO             TRANPORTE63
# 2         NaN  CLIENTE231         19       Nuevo León             TRANPORTE52
# 3  H000269818  CLIENTE232          2  BAJA CALIFORNIA             TRANPORTE72
# 4  N000100336  CLIENTE233         28       TAMAULIPAS             TRANPORTE26
#
#    C_ID_CONDUCTOR  ...      F_PESAJESALIDA TIPO_ASIGNACION TIPO_SERVICIO  \
# ...

# %%
df_2.shape
# Out:
# (5286, 34)

# %%
df_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5286 entries, 0 to 5285
# Data columns (total 34 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   PLANTAORIGEN             5286 non-null   object
#  1   FECHADESPACHO            5286 non-null   object
#  2   C_ID_VIAJE               5286 non-null   int64
#  3   FECHAVIAJE               5286 non-null   object
#  4   C_CLIENTE                2021 non-null   object
#  5   C_CLIENTE.1              5286 non-null   object
#  6   ID_ESTADO                5286 non-null   int64
#  7   ESTADO                   5286 non-null   object
#  8   D_EMPRESA_TRANSPORTISTA  5286 non-null   object
#  9   C_ID_CONDUCTOR           5286 non-null   int64
#  10  NOM_APE_COND             5286 non-null   object
#  11  TIPOCAMION               5286 non-null   object
#  12  TIPOTRANSPORTE           5286 non-null   object
#  13  TIPO_PRODUCTO            5286 non-null   object
# ...

# %% [markdown]
# ### Comprobemos que ambos df tienen la misma estructura

# %%
df_1.columns
# Out:
# Index(['PLANTAORIGEN', 'FECHADESPACHO', 'C_ID_VIAJE', 'FECHAVIAJE',
#        'C_CLIENTE', 'D_CLIENTE', 'ID_ESTADO', 'ESTADO',
#        'D_EMPRESA_TRANSPORTISTA', 'C_ID_CONDUCTOR', 'NOM_APE_COND',
#        'TIPO_SERVICIO', 'TIPOCAMION', 'TIPOTRANSPORTE', 'TIPO_PRODUCTO',
#        'TIPO_FORMA', 'CANT_PROGRAMADA', 'F_PRESENTACION', 'F_LLEGADANAVE',
#        'F_EGRESONAVE', 'F_INGRESOPLANTA', 'F_PESAJEENTRADA', 'F_ASIGVIAJE',
#        'F_INICIOCARGABULTO', 'F_FINCARGA', 'F_PESAJESALIDA', 'TIPO_ASIGNACION',
#        'C_PLANTA', 'D_PLANTA', 'TIPO_PERMISO', 'PESO_NETO', 'CAP_MAXIMA',
#        'ZONA_DESTINO', 'CUIDAD'],
#       dtype='object')

# %%
df_2.columns
# Out:
# Index(['PLANTAORIGEN', 'FECHADESPACHO', 'C_ID_VIAJE', 'FECHAVIAJE',
#        'C_CLIENTE', 'C_CLIENTE.1', 'ID_ESTADO', 'ESTADO',
#        'D_EMPRESA_TRANSPORTISTA', 'C_ID_CONDUCTOR', 'NOM_APE_COND',
#        'TIPOCAMION', 'TIPOTRANSPORTE', 'TIPO_PRODUCTO', 'TIPO_FORMA',
#        'Q_CANTIDAD', 'F_LLEGADANAVE', 'F_EGRESONAVE', 'F_PRESENTACION',
#        'F_INGRESOPLANTA', 'F_PESAJEENTRADA', 'F_ASIGVIAJE',
#        'F_InicioCargaBulto', 'F_FINCARGA', 'F_PESAJESALIDA', 'TIPO_ASIGNACION',
#        'TIPO_SERVICIO', 'C_PLANTA', 'D_PLANTA', 'TIPO_PERMISO', 'PESO_NETO',
#        'CAP_MAXIMA', 'ZONA_DESTINO', 'CUIDAD'],
#       dtype='object')

# %%
mask = df_1.columns != df_2.columns
mask
# Out:
# array([False, False, False, False, False,  True, False, False, False,
#        False, False,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#        False, False, False, False, False, False, False])

# %% [markdown]
# Hay algunas columnas que se llaman diferente, por lo que necesitamos saber si realmente son distintas

# %%
df_1.columns[mask]
# Out:
# Index(['D_CLIENTE', 'TIPO_SERVICIO', 'TIPOCAMION', 'TIPOTRANSPORTE',
#        'TIPO_PRODUCTO', 'TIPO_FORMA', 'CANT_PROGRAMADA', 'F_PRESENTACION',
#        'F_LLEGADANAVE', 'F_EGRESONAVE', 'F_INGRESOPLANTA', 'F_PESAJEENTRADA',
#        'F_ASIGVIAJE', 'F_INICIOCARGABULTO', 'F_FINCARGA', 'F_PESAJESALIDA',
#        'TIPO_ASIGNACION'],
#       dtype='object')

# %%
df_2.columns[mask]
# Out:
# Index(['C_CLIENTE.1', 'TIPOCAMION', 'TIPOTRANSPORTE', 'TIPO_PRODUCTO',
#        'TIPO_FORMA', 'Q_CANTIDAD', 'F_LLEGADANAVE', 'F_EGRESONAVE',
#        'F_PRESENTACION', 'F_INGRESOPLANTA', 'F_PESAJEENTRADA', 'F_ASIGVIAJE',
#        'F_InicioCargaBulto', 'F_FINCARGA', 'F_PESAJESALIDA', 'TIPO_ASIGNACION',
#        'TIPO_SERVICIO'],
#       dtype='object')

# %%
df_1.loc[:,mask].head()
# Out:
#     D_CLIENTE TIPO_SERVICIO                   TIPOCAMION  \
# 0   CLIENTE58            LO  Plataforma 3 ejes Neumática
# 1  CLIENTE132            LO  Plataforma 3 ejes Neumática
# 2   CLIENTE58            LO  Plataforma 3 ejes Neumática
# 3   CLIENTE58            LO  Plataforma 3 ejes Neumática
# 4  CLIENTE171            LO  Plataforma 3 ejes Neumática
#
#                 TIPOTRANSPORTE TIPO_PRODUCTO TIPO_FORMA  CANT_PROGRAMADA  \
# 0  Plataforma 3 ejes Neumática         ROLLO     PLANOS           38.386
# 1  Plataforma 3 ejes Neumática         ROLLO     PLANOS           31.572
# 2  Plataforma 3 ejes Neumática         ROLLO     PLANOS           39.265
# 3  Plataforma 3 ejes Neumática         ROLLO     PLANOS           39.900
# 4  Plataforma 3 ejes Neumática         ROLLO     PLANOS           31.677
#
#         F_PRESENTACION        F_LLEGADANAVE         F_EGRESONAVE  \
# 0  06-11-2022 18:54:00  06-11-2022 19:27:48  06-11-2022 23:11:45
# ...

# %%
df_2.loc[:,mask].head()
# Out:
#   C_CLIENTE.1                            TIPOCAMION  \
# 0   CLIENTE27   Plataforma 3 Ejes Neumática Cortina
# 1  CLIENTE198           Plataforma 3 ejes Neumática
# 2  CLIENTE231  Plataforma 3 ejes Neumática BIG COIL
# 3  CLIENTE232           Plataforma 3 ejes Neumática
# 4  CLIENTE233           Plataforma 3 ejes Neumática
#
#                          TIPOTRANSPORTE TIPO_PRODUCTO TIPO_FORMA  Q_CANTIDAD  \
# 0   Plataforma 3 Ejes Neumática Cortina         ROLLO     PLANOS      30.598
# 1           Plataforma 3 ejes Neumática         ROLLO     PLANOS      36.917
# 2  Plataforma 3 ejes Neumática BIG COIL         ROLLO     PLANOS      23.205
# 3           Plataforma 3 ejes Neumática         ROLLO     PLANOS      36.347
# 4           Plataforma 3 ejes Neumática         ROLLO     PLANOS      20.520
#
#         F_LLEGADANAVE        F_EGRESONAVE      F_PRESENTACION  \
# 0 2022-09-30 21:18:00 2022-10-01 01:10:25 2022-09-30 13:47:03
# ...

# %%
df_2 = df_2.rename(columns={'C_CLIENTE.1':'D_CLIENTE', 'Q_CANTIDAD':'CANT_PROGRAMADA',  'F_InicioCargaBulto':'F_INICIOCARGABULTO'})

# %%
df_2.head()
# Out:
#   PLANTAORIGEN        FECHADESPACHO  C_ID_VIAJE           FECHAVIAJE  \
# 0    Pesquería  01/10/2022 01:36:16    46227308  30/09/2022 23:59:00
# 1    Pesquería  01/10/2022 05:38:00    46248480  01/10/2022 14:13:00
# 2    Pesquería  01/10/2022 04:04:55    46260526  01/10/2022 23:59:00
# 3    Pesquería  01/10/2022 04:59:28    46252417  30/09/2022 17:44:00
# 4    Pesquería  01/10/2022 01:31:28    46246049  01/10/2022 11:47:00
#
#     C_CLIENTE   D_CLIENTE  ID_ESTADO           ESTADO D_EMPRESA_TRANSPORTISTA  \
# 0  N000003805   CLIENTE27          2  BAJA CALIFORNIA             TRANPORTE31
# 1  H000030812  CLIENTE198         11       GUANAJUATO             TRANPORTE63
# 2         NaN  CLIENTE231         19       Nuevo León             TRANPORTE52
# 3  H000269818  CLIENTE232          2  BAJA CALIFORNIA             TRANPORTE72
# 4  N000100336  CLIENTE233         28       TAMAULIPAS             TRANPORTE26
#
#    C_ID_CONDUCTOR  ...      F_PESAJESALIDA TIPO_ASIGNACION TIPO_SERVICIO  \
# ...

# %%
df_2['D_CLIENTE']
# Out:
# 0        CLIENTE27
# 1       CLIENTE198
# 2       CLIENTE231
# 3       CLIENTE232
# 4       CLIENTE233
#            ...
# 5281     CLIENTE58
# 5282    CLIENTE198
# 5283     CLIENTE95
# 5284     CLIENTE95
# 5285     CLIENTE95
# Name: D_CLIENTE, Length: 5286, dtype: object

# %% [markdown]
# darle reindex a las columnas pq sí tienen las mismas

# %%
df_2 = df_2.reindex(columns=['PLANTAORIGEN', 'FECHADESPACHO', 'C_ID_VIAJE', 'FECHAVIAJE',
       'C_CLIENTE', 'D_CLIENTE', 'ID_ESTADO', 'ESTADO',
       'D_EMPRESA_TRANSPORTISTA', 'C_ID_CONDUCTOR', 'NOM_APE_COND',
       'TIPO_SERVICIO', 'TIPOCAMION', 'TIPOTRANSPORTE', 'TIPO_PRODUCTO',
       'TIPO_FORMA', 'CANT_PROGRAMADA', 'F_PRESENTACION', 'F_LLEGADANAVE',
       'F_EGRESONAVE', 'F_INGRESOPLANTA', 'F_PESAJEENTRADA', 'F_ASIGVIAJE',
       'F_INICIOCARGABULTO', 'F_FINCARGA', 'F_PESAJESALIDA', 'TIPO_ASIGNACION',
       'C_PLANTA', 'D_PLANTA', 'TIPO_PERMISO', 'PESO_NETO', 'CAP_MAXIMA',
       'ZONA_DESTINO', 'CUIDAD'])

# %%
df_1.columns == df_2.columns
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True])

# %% [markdown]
# ### Combinando dataframes

# %%
df = pd.concat([df_1,df_2])

# %% [markdown]
# La cantidad de filas del nuevo df debe ser igual a la suma de la cantidad de filas de df1 y df2

# %%
can_total = df.shape[0]
can_1 = df_1.shape[0]
can_2 = df_2.shape[0]
can_total == can_1 + can_2
# Out:
# True

# %%
df.shape
# Out:
# (14440, 34)

# %% [markdown]
# **a) El dataset tiene 14440 registros y 34 columnas**

# %%
df.head()
# Out:
#   PLANTAORIGEN        FECHADESPACHO  C_ID_VIAJE           FECHAVIAJE  \
# 0     Guerrero  2022-11-06 23:19:19    47103405  05-11-2022 15:16:00
# 1     Guerrero  2022-11-16 14:58:16    47322566  19-11-2022 10:27:00
# 2     Guerrero  2022-11-18 07:14:21    47358720  18-11-2022 00:20:00
# 3     Guerrero  2022-11-19 07:46:41    47369172  18-11-2022 12:18:00
# 4     Guerrero  2022-11-23 15:13:51    47480917  23-11-2022 23:59:00
#
#     C_CLIENTE   D_CLIENTE  ID_ESTADO      ESTADO D_EMPRESA_TRANSPORTISTA  \
# 0         NaN   CLIENTE58         19  Nuevo León             TRANPORTE68
# 1         NaN  CLIENTE132         19  Nuevo Leon             TRANPORTE68
# 2         NaN   CLIENTE58         19  Nuevo León             TRANPORTE68
# 3         NaN   CLIENTE58         19  Nuevo León             TRANPORTE68
# 4  H000232500  CLIENTE171         19  NUEVO LEÓN             TRANPORTE68
#
#    C_ID_CONDUCTOR  ...           F_FINCARGA       F_PESAJESALIDA  \
# ...

# %%
df[['TIPOCAMION', 'TIPOTRANSPORTE']]
# Out:
#                                 TIPOCAMION  \
# 0              Plataforma 3 ejes Neumática
# 1              Plataforma 3 ejes Neumática
# 2              Plataforma 3 ejes Neumática
# 3              Plataforma 3 ejes Neumática
# 4              Plataforma 3 ejes Neumática
# ...                                    ...
# 5281  Plataforma 3 ejes Neumática BIG COIL
# 5282           Plataforma 3 ejes Neumática
# 5283           Plataforma 3 ejes Neumática
# 5284           Plataforma 3 ejes Neumática
# 5285           Plataforma 3 ejes Neumática
#
#                             TIPOTRANSPORTE
# 0              Plataforma 3 ejes Neumática
# 1              Plataforma 3 ejes Neumática
# 2              Plataforma 3 ejes Neumática
# 3              Plataforma 3 ejes Neumática
# 4              Plataforma 3 ejes Neumática
# ...                                    ...
# 5281  Plataforma 3 ejes Neumática BIG COIL
# 5282           Plataforma 3 ejes Neumática
# 5283           Plataforma 3 ejes Neumática
# ...

# %% [markdown]
# verificar que tengan el mismo contenido

# %%
df.loc[df['TIPOCAMION'].ne(df['TIPOTRANSPORTE'])][['TIPOCAMION', 'TIPOTRANSPORTE']]
# Out:
#                              TIPOCAMION                     TIPOTRANSPORTE
# 225   Plataforma 3 ejes Neumática Corta  Plataforma 3 Ejes Neumática Corta
# 226   Plataforma 3 ejes Neumática Corta  Plataforma 3 Ejes Neumática Corta
# 227   Plataforma 3 ejes Neumática Corta  Plataforma 3 Ejes Neumática Corta
# 228   Plataforma 3 ejes Neumática Corta  Plataforma 3 Ejes Neumática Corta
# 229   Plataforma 3 ejes Neumática Corta  Plataforma 3 Ejes Neumática Corta
# ...                                 ...                                ...
# 5155  Plataforma 3 ejes Neumática Corta  Plataforma 3 Ejes Neumática Corta
# 5161  Plataforma 3 ejes Neumática Corta  Plataforma 3 Ejes Neumática Corta
# 5166  Plataforma 3 ejes Neumática Corta  Plataforma 3 Ejes Neumática Corta
# 5169  Plataforma 3 ejes Neumática Corta  Plataforma 3 Ejes Neumática Corta
# 5238  Plataforma 3 ejes Neumática Corta  Plataforma 3 Ejes Neumática Corta
#
# [1333 rows x 2 columns]

# %%
del(df['TIPOCAMION'])

# %%
df.shape
# Out:
# (14440, 33)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 14440 entries, 0 to 5285
# Data columns (total 33 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   PLANTAORIGEN             14440 non-null  object
#  1   FECHADESPACHO            14440 non-null  object
#  2   C_ID_VIAJE               14440 non-null  int64
#  3   FECHAVIAJE               14440 non-null  object
#  4   C_CLIENTE                6902 non-null   object
#  5   D_CLIENTE                14422 non-null  object
#  6   ID_ESTADO                14440 non-null  int64
#  7   ESTADO                   14440 non-null  object
#  8   D_EMPRESA_TRANSPORTISTA  14440 non-null  object
#  9   C_ID_CONDUCTOR           14440 non-null  int64
#  10  NOM_APE_COND             14439 non-null  object
#  11  TIPO_SERVICIO            14440 non-null  object
#  12  TIPOTRANSPORTE           14440 non-null  object
#  13  TIPO_PRODUCTO            14440 non-null  object
# ...

# %%
df[['C_PLANTA', 'D_PLANTA']]
# Out:
#      C_PLANTA   D_PLANTA
# 0         GUE   Guerrero
# 1         GUE   Guerrero
# 2         GUE   Guerrero
# 3         GUE   Guerrero
# 4         GUE   Guerrero
# ...       ...        ...
# 5281      PSQ  Pesquería
# 5282      PSQ  Pesquería
# 5283      PSQ  Pesquería
# 5284      PSQ  Pesquería
# 5285      PSQ  Pesquería
#
# [14440 rows x 2 columns]

# %%
del(df['C_PLANTA'])
del(df['D_PLANTA'])

# %%
df[df['D_CLIENTE'] == 'CLIENTE58']
# Out:
#      PLANTAORIGEN        FECHADESPACHO  C_ID_VIAJE           FECHAVIAJE  \
# 0        Guerrero  2022-11-06 23:19:19    47103405  05-11-2022 15:16:00
# 2        Guerrero  2022-11-18 07:14:21    47358720  18-11-2022 00:20:00
# 3        Guerrero  2022-11-19 07:46:41    47369172  18-11-2022 12:18:00
# 5        Guerrero  2022-11-27 08:36:17    47559913  27-11-2022 00:18:00
# 10       Guerrero  2022-11-18 23:06:02    47351989  17-11-2022 17:24:00
# ...           ...                  ...         ...                  ...
# 5241    Pesquería  19/10/2022 21:57:39    46704148  18/10/2022 16:12:00
# 5264    Pesquería  19/10/2022 22:41:37    46723195  19/10/2022 10:06:00
# 5277    Pesquería  19/10/2022 23:42:01    46734992  20/10/2022 23:59:00
# 5279    Pesquería  19/10/2022 23:39:06    46729689  30/10/2022 16:06:00
# 5281    Pesquería  19/10/2022 22:40:27    46729690  30/10/2022 16:06:00
#
#      C_CLIENTE  D_CLIENTE  ID_ESTADO      ESTADO D_EMPRESA_TRANSPORTISTA  \
# ...

# %%
df['TIPOTRANSPORTE'].unique()
# Out:
# array(['Plataforma 3 ejes Neumática', 'Plataforma 2 ejes Muelles',
#        'Plataforma 2 ejes Neumática', 'Torton',
#        'Plataforma 3 Ejes Neumática Cortina',
#        'Plataforma 3 Ejes Neumática Corta',
#        'Plataforma 3 Ejes Neumática Ultra Ligera',
#        'Plataforma 3 ejes Neumática Cortina',
#        'Plataforma 3 ejes Neumática BIG COIL', 'TOLVA',
#        'Plataforma 3 ejes Muelles',
#        'Plataforma 3 Ejes Neumática Corta Ligera',
#        'Plataforma 3 ejes Neumática Portacintas',
#        'Caja seca 2 ejes Neumática', 'Caja seca 2 ejes Neumática Larga'],
#       dtype=object)

# %%
df['TIPO_FORMA'].unique()
# Out:
# array(['PLANOS', 'PLANOS,TUBOS', 'TUBOS', 'POLIN', 'SUBPRODUCTOS',
#        'PLANOS,POLIN', 'LARGOS'], dtype=object)

# %%
df['TIPO_PRODUCTO'].unique()
# Out:
# array(['ROLLO', 'CINTA', 'HOJA', 'CINTA,ROLLO', 'CINTA,HOJA',
#        'CUADRADO,ROLLO', 'CUADRADO', 'CUADRADO,REDONDO', 'BANDA,ROLLO',
#        'POLIN Z', 'BANDA', 'CHATARRA', 'CINTA,POLIN Z', 'REDONDO',
#        'CUADRADO,REDONDO,ROLLO', 'CUADRADO,RECTANGULAR,REDONDO',
#        'HOJA,ROLLO', 'BANDA,HOJA', 'ALAMBRON', 'RECTANGULAR',
#        'RECTANGULAR,REDONDO', 'CINTA,HOJA,ROLLO', 'CUADRADO,RECTANGULAR'],
#       dtype=object)

# %%
df.groupby('TIPO_FORMA')['TIPO_PRODUCTO'].unique()
# Out:
# TIPO_FORMA
# LARGOS                                                 [ALAMBRON]
# PLANOS          [ROLLO, CINTA, HOJA, CINTA,ROLLO, CINTA,HOJA, ...
# PLANOS,POLIN                                      [CINTA,POLIN Z]
# PLANOS,TUBOS             [CUADRADO,ROLLO, CUADRADO,REDONDO,ROLLO]
# POLIN                                                   [POLIN Z]
# SUBPRODUCTOS                                           [CHATARRA]
# TUBOS           [CUADRADO, CUADRADO,REDONDO, REDONDO, CUADRADO...
# Name: TIPO_PRODUCTO, dtype: object

# %% [markdown]
# ## Exploración de los datos

# %% [markdown]
# ### **1)Calcula medidas estadísticas**

# %%
df.columns
# Out:
# Index(['PLANTAORIGEN', 'FECHADESPACHO', 'C_ID_VIAJE', 'FECHAVIAJE',
#        'C_CLIENTE', 'D_CLIENTE', 'ID_ESTADO', 'ESTADO',
#        'D_EMPRESA_TRANSPORTISTA', 'C_ID_CONDUCTOR', 'NOM_APE_COND',
#        'TIPO_SERVICIO', 'TIPOTRANSPORTE', 'TIPO_PRODUCTO', 'TIPO_FORMA',
#        'CANT_PROGRAMADA', 'F_PRESENTACION', 'F_LLEGADANAVE', 'F_EGRESONAVE',
#        'F_INGRESOPLANTA', 'F_PESAJEENTRADA', 'F_ASIGVIAJE',
#        'F_INICIOCARGABULTO', 'F_FINCARGA', 'F_PESAJESALIDA', 'TIPO_ASIGNACION',
#        'TIPO_PERMISO', 'PESO_NETO', 'CAP_MAXIMA', 'ZONA_DESTINO', 'CUIDAD'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 14440 entries, 0 to 5285
# Data columns (total 31 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   PLANTAORIGEN             14440 non-null  object
#  1   FECHADESPACHO            14440 non-null  object
#  2   C_ID_VIAJE               14440 non-null  int64
#  3   FECHAVIAJE               14440 non-null  object
#  4   C_CLIENTE                6902 non-null   object
#  5   D_CLIENTE                14422 non-null  object
#  6   ID_ESTADO                14440 non-null  int64
#  7   ESTADO                   14440 non-null  object
#  8   D_EMPRESA_TRANSPORTISTA  14440 non-null  object
#  9   C_ID_CONDUCTOR           14440 non-null  int64
#  10  NOM_APE_COND             14439 non-null  object
#  11  TIPO_SERVICIO            14440 non-null  object
#  12  TIPOTRANSPORTE           14440 non-null  object
#  13  TIPO_PRODUCTO            14440 non-null  object
# ...

# %%
df['C_ID_VIAJE'] = df['C_ID_VIAJE'].astype(object)
df['ID_ESTADO'] = df['ID_ESTADO'].astype(object)
df['C_ID_CONDUCTOR'] = df['C_ID_CONDUCTOR'].astype(object)

# %%
len(df.columns)
# Out:
# 31

# %% [markdown]
#  Variables cuantitativas

# %%
cuantitativas = ['CANT_PROGRAMADA', 'PESO_NETO', 'CAP_MAXIMA']

# %%
 df_num = df.loc[:, cuantitativas]

# %%
 df_num.describe()
# Out:
#        CANT_PROGRAMADA     PESO_NETO    CAP_MAXIMA
# count     14440.000000  14440.000000  14440.000000
# mean         28.708958  27319.924515     53.244564
# std           7.777753   9583.709046      3.846130
# min           0.818000      0.000000     24.500000
# 25%          21.739500  21407.500000     54.000000
# 50%          29.763500  28840.000000     54.000000
# 75%          35.660750  35210.000000     54.000000
# max          41.446000  41200.000000     63.000000

# %%
estadisticas_cuantitativas = pd.DataFrame(columns=['variable', 'promedio', 'mediana', 'moda', 'maximo', 'minimo', 'rango', 'varianza', 'desviacion_estandar'])

for column in cuantitativas: 
  df_variable = df[column]

  # Calcular medidas de tendencia central
  promedio = df_variable.mean()
  mediana = df_variable.median()
  moda_ = df_variable.mode()

  if len(moda_) == 1:
    moda = moda_[0]
  else:
    moda = [moda_[i] for i in range(len(moda_))]

  # Calcular medidas de dispersión
  maximo = df_variable.max()
  minimo = df_variable.min()
  rango = df_variable.max() - df_variable.min()
  varianza = df_variable.var()
  desviacion_estandar = df_variable.std()

  # Agregar a un nuevo data frame
  nuevo_registro = {'variable': column, 'promedio': promedio, 'mediana': mediana, 'moda': moda, 'maximo': maximo,
                    'minimo': minimo, 'rango': rango, 'varianza': varianza, 'desviacion_estandar': desviacion_estandar}
  estadisticas_cuantitativas = pd.concat([estadisticas_cuantitativas, pd.DataFrame([nuevo_registro])], ignore_index=True)

# %%
estadisticas_cuantitativas
# Out:
#           variable      promedio     mediana    moda     maximo  minimo  \
# 0  CANT_PROGRAMADA     28.708958     29.7635  25.929     41.446   0.818
# 1        PESO_NETO  27319.924515  28840.0000   0.000  41200.000   0.000
# 2       CAP_MAXIMA     53.244564     54.0000  54.000     63.000  24.500
#
#        rango      varianza  desviacion_estandar
# 0     40.628  6.049344e+01             7.777753
# 1  41200.000  9.184748e+07          9583.709046
# 2     38.500  1.479272e+01             3.846130

# %% [markdown]
# Variables cualitativas o categóricas

# %%
cualitativas = ['PLANTAORIGEN', 'C_ID_VIAJE',
       'C_CLIENTE', 'D_CLIENTE', 'ID_ESTADO', 'ESTADO',
       'D_EMPRESA_TRANSPORTISTA', 'C_ID_CONDUCTOR', 'NOM_APE_COND',
       'TIPO_SERVICIO', 'TIPOTRANSPORTE', 'TIPO_PRODUCTO', 'TIPO_FORMA',
       'TIPO_ASIGNACION','TIPO_PERMISO','ZONA_DESTINO', 'CUIDAD' ]

# %%
df.describe(include='object')
# Out:
#        PLANTAORIGEN        FECHADESPACHO  C_ID_VIAJE           FECHAVIAJE  \
# count         14440                14440       14440                14440
# unique            2                12784       12797                 4145
# top        Guerrero  2022-10-28 18:45:43    46927909  13/10/2022 23:59:00
# freq           9154                   31          31                  217
#
#          C_CLIENTE  D_CLIENTE  ID_ESTADO      ESTADO D_EMPRESA_TRANSPORTISTA  \
# count         6902      14422      14440       14440                   14440
# unique         232        273         26          41                      91
# top     H000269647  CLIENTE58         19  Nuevo León             TRANPORTE68
# freq           783       2243      11714        5264                    1666
#
#         C_ID_CONDUCTOR  ...      F_INGRESOPLANTA      F_PESAJEENTRADA  \
# count            14440  ...                14439                13813
# ...

# %%
len(cualitativas)
# Out:
# 17

# %%
# Crear un dataframe vacío 
estadisticas_cualitativas = pd.DataFrame(columns=['variable', 'frecuencia', 'moda'])

for column in cualitativas:
    df_variable = df[column]
    
    # Calcular la tabla de distribución de frecuencia y moda
    frecuencia = df_variable.value_counts()
    moda_ = df_variable.mode()

    if len(moda_) == 1:
        moda = moda_[0]
    else:
        moda = [moda_[i] for i in range(len(moda_))]
    
    # Agregar  a un nuevo registro en el dataframe
    nuevo_registro = {'variable': column, 'frecuencia': frecuencia, 'moda': moda}
    estadisticas_cualitativas = pd.concat([estadisticas_cualitativas, pd.DataFrame([nuevo_registro])], ignore_index=True)

# %%
estadisticas_cualitativas
# Out:
#                    variable  \
# 0              PLANTAORIGEN
# 1                C_ID_VIAJE
# 2                 C_CLIENTE
# 3                 D_CLIENTE
# 4                 ID_ESTADO
# 5                    ESTADO
# 6   D_EMPRESA_TRANSPORTISTA
# 7            C_ID_CONDUCTOR
# 8              NOM_APE_COND
# 9             TIPO_SERVICIO
# 10           TIPOTRANSPORTE
# 11            TIPO_PRODUCTO
# 12               TIPO_FORMA
# 13          TIPO_ASIGNACION
# 14             TIPO_PERMISO
# 15             ZONA_DESTINO
# 16                   CUIDAD
#
#                                            frecuencia  \
# 0   Guerrero     9154
# Pesquería    5286
# Name: PLAN...
# 1   46927909    31
# 46440893    24
# 46461286    24
# 4...
# 2   H000269647    783
# H000126500    596
# H010005034...
# 3   CLIENTE58     2243
# CLIENTE224    1001
# CLIENTE1...
# 4   19    11714
# 5       747
# 28      718
# 7       22...
# 5   Nuevo León          5264
# NUEVO LEÓN          5...
# 6   TRANPORTE68    1666
# ...

# %%
estadisticas_cualitativas.iloc[0]['frecuencia']
# Out:
# Guerrero     9154
# Pesquería    5286
# Name: PLANTAORIGEN, dtype: int64

# %%
estadisticas_cualitativas.iloc[1]['frecuencia']
# Out:
# 46927909    31
# 46440893    24
# 46461286    24
# 46810998    23
# 47231837    22
#             ..
# 47099186     1
# 47112185     1
# 47168113     1
# 47160185     1
# 46721196     1
# Name: C_ID_VIAJE, Length: 12797, dtype: int64

# %%
estadisticas_cualitativas.iloc[2]['frecuencia']
# Out:
# H000269647    783
# H000126500    596
# H010005034    582
# H000122204    459
# H000041807    421
#              ...
# N000003229      1
# H000148811      1
# N000190867      1
# H000148817      1
# N000100782      1
# Name: C_CLIENTE, Length: 232, dtype: int64

# %%
estadisticas_cualitativas.iloc[3]['frecuencia']
# Out:
# CLIENTE58     2243
# CLIENTE224    1001
# CLIENTE157     783
# CLIENTE190     711
# CLIENTE177     596
#               ...
# CLIENTE143       1
# CLIENTE20        1
# CLIENTE162       1
# CLIENTE56        1
# CLIENTE86        1
# Name: D_CLIENTE, Length: 273, dtype: int64

# %%
estadisticas_cualitativas.iloc[4]['frecuencia']
# Out:
# 19    11714
# 5       747
# 28      718
# 7       229
# 24      176
# 15      174
# 2       169
# 29      138
# 11       69
# 8        59
# 14       54
# 22       42
# 9        28
# 26       20
# 13       19
# 10       19
# 6        18
# 1        15
# 30        9
# 21        8
# 31        6
# 17        3
# 25        2
# 16        2
# 27        1
# 20        1
# Name: ID_ESTADO, dtype: int64

# %%
estadisticas_cualitativas.iloc[5]['frecuencia']
# Out:
# Nuevo León          5264
# NUEVO LEÓN          5017
# Nuevo Leon          1281
# TAMAULIPAS           714
# COAHUILA             630
# Coahuila             229
# BAJA CALIFORNIA      167
# Nuevo LeÃ³n          152
# Tamaulipas           136
# Mexico               121
# Chiapas              117
# San Luis Potosí       94
# SAN LUIS POTOSÍ       73
# GUANAJUATO            65
# CHIHUAHUA             59
# ESTADO DE MÉXICO      53
# QUERÉTARO             42
# Jalisco               33
# CIUDAD DE MÉXICO      28
# JALISCO               21
# HIDALGO               19
# DURANGO               19
# Chihuahua             18
# SONORA                17
# AGUASCALIENTES        15
# San Luis Potosi        9
# PUEBLA                 7
# TLAXCALA               6
# VERACRUZ               5
# Veracruz               4
# Guanajuato             4
# MORELOS                3
# Yucatán                3
# YUCATÁN                3
# Sonora                 3
# SINALOA                2
# MICHOACÁN              2
# ...

# %%
estadisticas_cualitativas.iloc[6]['frecuencia']
# Out:
# TRANPORTE68    1666
# TRANPORTE53    1462
# TRANPORTE38    1242
# TRANPORTE59    1069
# TRANPORTE63    1021
#                ...
# TRANPORTE89       1
# TRANPORTE87       1
# TRANPORTE5        1
# TRANPORTE36       1
# TRANPORTE94       1
# Name: D_EMPRESA_TRANSPORTISTA, Length: 91, dtype: int64

# %%
estadisticas_cualitativas.iloc[7]['frecuencia']
# Out:
# 92866     312
# 93343     216
# 95974     125
# 108935     62
# 79840      59
#          ...
# 107514      1
# 107351      1
# 106036      1
# 87233       1
# 110638      1
# Name: C_ID_CONDUCTOR, Length: 1547, dtype: int64

# %%
estadisticas_cualitativas.iloc[8]['frecuencia']
# Out:
# CHOFER769     312
# CHOFER199     216
# CHOFER103     125
# CHOFER899      62
# CHOFER56       59
#              ...
# CHOFER411       1
# CHOFER1412      1
# CHOFER413       1
# CHOFER419       1
# CHOFER1798      1
# Name: NOM_APE_COND, Length: 1793, dtype: int64

# %%
estadisticas_cualitativas.iloc[9]['frecuencia']
# Out:
# LO    13432
# FO     1008
# Name: TIPO_SERVICIO, dtype: int64

# %%
estadisticas_cualitativas.iloc[10]['frecuencia']
# Out:
# Plataforma 3 ejes Neumática                 7727
# Plataforma 3 ejes Neumática BIG COIL        3202
# Plataforma 3 Ejes Neumática Corta           1307
# Plataforma 3 Ejes Neumática Cortina          657
# Plataforma 2 ejes Neumática                  409
# Plataforma 3 ejes Neumática Cortina          379
# Plataforma 3 Ejes Neumática Ultra Ligera     285
# Torton                                       221
# Plataforma 3 ejes Muelles                     90
# Plataforma 3 Ejes Neumática Corta Ligera      90
# Plataforma 3 ejes Neumática Portacintas       26
# Plataforma 2 ejes Muelles                     17
# TOLVA                                         14
# Caja seca 2 ejes Neumática Larga               9
# Caja seca 2 ejes Neumática                     7
# Name: TIPOTRANSPORTE, dtype: int64

# %%
estadisticas_cualitativas.iloc[11]['frecuencia']
# Out:
# ROLLO                           11540
# CINTA                            1725
# HOJA                              371
# CINTA,HOJA                        275
# CINTA,ROLLO                        95
# CHATARRA                           92
# REDONDO                            68
# CUADRADO,REDONDO                   68
# BANDA                              43
# CUADRADO                           36
# BANDA,ROLLO                        34
# HOJA,ROLLO                         19
# CUADRADO,RECTANGULAR,REDONDO       14
# POLIN Z                            13
# CINTA,HOJA,ROLLO                   10
# ALAMBRON                           10
# RECTANGULAR,REDONDO                 9
# CUADRADO,ROLLO                      6
# RECTANGULAR                         4
# CINTA,POLIN Z                       3
# CUADRADO,REDONDO,ROLLO              2
# BANDA,HOJA                          2
# CUADRADO,RECTANGULAR                1
# Name: TIPO_PRODUCTO, dtype: int64

# %%
estadisticas_cualitativas.iloc[12]['frecuencia']
# Out:
# PLANOS          14114
# TUBOS             200
# SUBPRODUCTOS       92
# POLIN              13
# LARGOS             10
# PLANOS,TUBOS        8
# PLANOS,POLIN        3
# Name: TIPO_FORMA, dtype: int64

# %%
estadisticas_cualitativas.iloc[13]['frecuencia']
# Out:
# MANUAL        6408
# AUTOMATICA    1401
# Name: TIPO_ASIGNACION, dtype: int64

# %%
estadisticas_cualitativas.iloc[14]['frecuencia']
# Out:
# Traslado Externo               6871
# Cliente ENVIA                  6779
# Traslado Externo sin Pesada     634
# Despacho                        156
# Name: TIPO_PERMISO, dtype: int64

# %%
estadisticas_cualitativas.iloc[15]['frecuencia']
# Out:
# 0                            14019
# Customizados MP (M3)           253
# MP CSI Apodaca Horizontal       66
# Bodega Del Carmen FFCC          56
# Bodega Foremex FFCC              8
# Zna PNE                          8
# MP Acabados                      5
# Logistica 3                      4
# Norte                            3
# Nave 6 Recubiertos               3
# Pegi TPG Primera                 3
# Nave 5 Ojo Horizontal            2
# Frios Oriente Norte N1           2
# MP CSI Apodaca Vertical          2
# MP Galvanizado II                2
# Playa Norte de Rollos            2
# Salida TMP Entrada TNS           1
# Decapado                         1
# Name: ZONA_DESTINO, dtype: int64

# %%
estadisticas_cualitativas.iloc[16]['frecuencia']
# Out:
# APODACA                 2829
# Monterrey               2256
# San Nicolas de los G    1880
# GRAL ESCOBEDO            980
# Pesqueria                949
#                         ...
# GARCIA, NUEVO LEON         1
# ECUANDUREO                 1
# PARAISO                    1
# CIUDAD FRONTERA            1
# SILAO                      1
# Name: CUIDAD, Length: 107, dtype: int64

# %% [markdown]
# ### **2) Explora los datos usando herramientas de visualización**

# %% [markdown]
# **Variables cuantitativas**

# %%
# set the size of the figure
sns.set(rc={'figure.figsize':(7,5)})

# plot a histogram showing the distribution of the target values
sns.histplot(df['CANT_PROGRAMADA'], bins=10)

# add vertical lines for the mean and median
plt.axvline(x=df['CANT_PROGRAMADA'].mean(), color='red', linestyle='dashed', linewidth=2)
plt.axvline(x=df['CANT_PROGRAMADA'].median(), color='green', linestyle='dashed', linewidth=2)

plt.show()

# %% [markdown]
# Es asimétrica pues está sesgada hacia la izquierda o hacia los valores menores.

# %%
# set the size of the figure
sns.set(rc={'figure.figsize':(7,5)})

# plot a histogram showing the distribution of the target values
sns.displot(df['PESO_NETO'], bins=10)

# add vertical lines for the mean and median
plt.axvline(x=df['PESO_NETO'].mean(), color='red', linestyle='dashed', linewidth=2)
plt.axvline(x=df['PESO_NETO'].median(), color='green', linestyle='dashed', linewidth=2)

plt.show()

# %% [markdown]
# Es asimétrica pues está sesgada hacia la izquierda o hacia los valores menores.

# %%
# plot a histogram showing the distribution of the target values
sns.displot(df['CAP_MAXIMA'], bins=10)
# add vertical lines for the mean and median
plt.axvline(x=df['CAP_MAXIMA'].mean(), color='red', linestyle='dashed', linewidth=2)
plt.axvline(x=df['CAP_MAXIMA'].median(), color='green', linestyle='dashed', linewidth=2)
plt.show()

# %% [markdown]
# Es un poco asimétrica pues está ligeramente sesgada hacia la izquierda o hacia los valores menores.

# %%
plt.boxplot(df['PESO_NETO'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7fcb984c7250>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7fcb984c7790>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7fcb984c6fb0>],
#  'medians': [<matplotlib.lines.Line2D at 0x7fcb984c7cd0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7fcb984c7f70>],
#  'means': []}

# %% [markdown]
# Hay valores átipicos con 0 y la mayorái de los valoes se encuntran entre 20000 y 35000.

# %%
plt.boxplot(df['CAP_MAXIMA'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7fcb984d55a0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7fcb984d5ae0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7fcb984d5300>],
#  'medians': [<matplotlib.lines.Line2D at 0x7fcb984d6020>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7fcb984d62c0>],
#  'means': []}

# %% [markdown]
# la mayoría de los valores estan entre 50 y 55 pues los cuartiles están ahí, y contamos con valores atípicos de más de 60 y hasta de 25.

# %%
plt.boxplot(df['CANT_PROGRAMADA'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7fcbd9629030>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7fcbd9629570>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7fcbd9628d90>],
#  'medians': [<matplotlib.lines.Line2D at 0x7fcbd9629ab0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7fcbd9629d50>],
#  'means': []}

# %% [markdown]
# La mayoría de los valores están alrededor de su mediana, entre 20 y 35, pero hay valores atípicos con 0.

# %%
df[cuantitativas].corr(method='pearson')
# Out:
#                  CANT_PROGRAMADA  PESO_NETO  CAP_MAXIMA
# CANT_PROGRAMADA         1.000000   0.716711    0.338885
# PESO_NETO               0.716711   1.000000    0.246934
# CAP_MAXIMA              0.338885   0.246934    1.000000

# %%
correlation_matrix = df[cuantitativas].corr(method='pearson')
sns.heatmap(data=correlation_matrix, annot=True)
# Out:
# <Axes: >

# %% [markdown]
# Las variables que muestran una alta correlación son PESO_NETO y CANT_PROGRAMADA

# %% [markdown]
# **Variables cualitativas**

# %%
cualitativas
# Out:
# ['PLANTAORIGEN',
#  'C_ID_VIAJE',
#  'C_CLIENTE',
#  'D_CLIENTE',
#  'ID_ESTADO',
#  'ESTADO',
#  'D_EMPRESA_TRANSPORTISTA',
#  'C_ID_CONDUCTOR',
#  'NOM_APE_COND',
#  'TIPO_SERVICIO',
#  'TIPOTRANSPORTE',
#  'TIPO_PRODUCTO',
#  'TIPO_FORMA',
#  'TIPO_ASIGNACION',
#  'TIPO_PERMISO',
#  'ZONA_DESTINO',
#  'CUIDAD']

# %%
df.PLANTAORIGEN.value_counts().plot(kind="bar",alpha=0.5)  
plt.title('PLANTAORIGEN')
plt.show()

# %%
df.PLANTAORIGEN.value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='PLANTAORIGEN'>

# %% [markdown]
# La mayoría de los resgistros pertenecen a la planta Guerrero.

# %%
n = 15
top_n = df['C_CLIENTE'].value_counts().nlargest(n)
top_n.plot(kind='bar', alpha=0.5)
plt.title('C_CLIENTE')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(7, 7))

counts = df['C_CLIENTE'].value_counts()
threshold = 0.03 # definir el umbral para agrupar valores en 'Otros'

# agrupar valores en 'Otros' si la frecuencia es menor que el umbral
mask = counts / counts.sum() < threshold
other = counts[mask].sum()
counts = counts[~mask]
counts['Otros'] = other

# plotear el gráfico de pastel
counts.plot(kind='pie', ax=ax, autopct='%1.1f%%', startangle=90, legend=True, labels=None)

# agregar los nombres de las categorías en el centro del gráfico
ax.set_title('Distribución de C_CLIENTE')
ax.legend(labels=counts.index, loc='upper left', bbox_to_anchor=(1, 0.5))

plt.show()

# %%
n = 15
top_n = df['D_CLIENTE'].value_counts().nlargest(n)
top_n.plot(kind='bar', alpha=0.5)
plt.title('D_CLIENTE')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(7, 7))

counts = df['D_CLIENTE'].value_counts()
threshold = 0.03 # definir el umbral para agrupar valores en 'Otros'

# agrupar valores en 'Otros' si la frecuencia es menor que el umbral
mask = counts / counts.sum() < threshold
other = counts[mask].sum()
counts = counts[~mask]
counts['Otros'] = other

# plotear el gráfico de pastel
counts.plot(kind='pie', ax=ax, autopct='%1.1f%%', startangle=90, legend=True, labels=None)

# agregar los nombres de las categorías en el centro del gráfico
ax.set_title('Distribución de D_CLIENTE')
ax.legend(labels=counts.index, loc='upper left', bbox_to_anchor=(1, 0.5))

plt.show()

# %% [markdown]
# El CLIENTE 58 es el que tiene más resgistros.

# %%
n = 5
top_n = df['ID_ESTADO'].value_counts().nlargest(n)
top_n.plot(kind='bar', alpha=0.5)
plt.title('ID_ESTADO')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(7, 7))

counts = df['ID_ESTADO'].value_counts()
threshold = 0.015 # definir el umbral para agrupar valores en 'Otros'

# agrupar valores en 'Otros' si la frecuencia es menor que el umbral
mask = counts / counts.sum() < threshold
other = counts[mask].sum()
counts = counts[~mask]
counts['Otros'] = other

# plotear el gráfico de pastel
counts.plot(kind='pie', ax=ax, autopct='%1.1f%%', startangle=90, legend=True, labels=None)

# agregar los nombres de las categorías en el centro del gráfico
ax.set_title('Distribución de ID_ESTADO')
ax.legend(labels=counts.index, loc='upper left', bbox_to_anchor=(1, 0.5))

plt.show()

# %% [markdown]
# El esatdo con el Id 19, Nuevo León, es al que más se viaja.

# %%
n = 10
top_n = df['ESTADO'].value_counts().nlargest(n)
top_n.plot(kind='bar', alpha=0.5)
plt.title('ESTADO')
plt.show()

# %% [markdown]
# Hay bastantes inconsistencias con los nombres de los estados, pues Nuevo León aparece escrito de distintas formas lo que causa que se tome como si fuesen dos estados diferentes

# %%
fig, ax = plt.subplots(figsize=(7, 7))

counts = df['ESTADO'].value_counts()
threshold = 0.015 # definir el umbral para agrupar valores en 'Otros'

# agrupar valores en 'Otros' si la frecuencia es menor que el umbral
mask = counts / counts.sum() < threshold
other = counts[mask].sum()
counts = counts[~mask]
counts['Otros'] = other

# plotear el gráfico de pastel
counts.plot(kind='pie', ax=ax, autopct='%1.1f%%', startangle=90, legend=True, labels=None)

# agregar los nombres de las categorías en el centro del gráfico
ax.set_title('Distribución de ESTADO')
ax.legend(labels=counts.index, loc='upper left', bbox_to_anchor=(1, 0.5))

plt.show()

# %% [markdown]
# Más de la mitad de los viajes son en Nuveo León.

# %%
n = 15
top_n = df['D_EMPRESA_TRANSPORTISTA'].value_counts().nlargest(n)
top_n.plot(kind='bar', alpha=0.5)
plt.title('D_EMPRESA_TRANSPORTISTA')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(7, 7))

counts = df['D_EMPRESA_TRANSPORTISTA'].value_counts()
threshold = 0.03 # definir el umbral para agrupar valores en 'Otros'

# agrupar valores en 'Otros' si la frecuencia es menor que el umbral
mask = counts / counts.sum() < threshold
other = counts[mask].sum()
counts = counts[~mask]
counts['Otros'] = other

# plotear el gráfico de pastel
counts.plot(kind='pie', ax=ax, autopct='%1.1f%%', startangle=90, legend=True, labels=None)

# agregar los nombres de las categorías en el centro del gráfico
ax.set_title('Distribución de D_EMPRESA_TRANSPORTISTA')
ax.legend(labels=counts.index, loc='upper left', bbox_to_anchor=(1, 0.5))

plt.show()

# %% [markdown]
# Transporte68 y 53 son los que tiene mayor presencia, pero no ocupan la mayoría de los viajes.

# %%
n = 15
top_n = df['C_ID_CONDUCTOR'].value_counts().nlargest(n)
top_n.plot(kind='bar', alpha=0.5)
# Out:
# <Axes: >

# %%
n = 15
top_n = df['NOM_APE_COND'].value_counts().nlargest(n)
top_n.plot(kind='bar', alpha=0.5)
# Out:
# <Axes: >

# %%
fig, ax = plt.subplots(figsize=(7, 7))

counts = df['NOM_APE_COND'].value_counts()
threshold = 0.005 # definir el umbral para agrupar valores en 'Otros'

# agrupar valores en 'Otros' si la frecuencia es menor que el umbral
mask = counts / counts.sum() < threshold
other = counts[mask].sum()
counts = counts[~mask]
counts['Otros'] = other

# plotear el gráfico de pastel
counts.plot(kind='pie', ax=ax, autopct='%1.1f%%', startangle=90, legend=True, labels=None)

# agregar los nombres de las categorías en el centro del gráfico
ax.set_title('Distribución de NOM_APE_COND')
ax.legend(labels=counts.index, loc='upper left', bbox_to_anchor=(1, 0.5))

plt.show()

# %% [markdown]
# El chofer con más viajes es CHOFER769, pero no hay diferencia demasido grande con la cantidad de viajes asignada a otros conductores.

# %%
df.TIPO_SERVICIO.value_counts().plot(kind="bar",alpha=0.5)
# Out:
# <Axes: >

# %%
df.TIPO_SERVICIO.value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='TIPO_SERVICIO'>

# %% [markdown]
# Casi todos los viajes que se asignaron fueron locales.

# %%
df.TIPOTRANSPORTE.value_counts().plot(kind="bar",alpha=0.5)
# Out:
# <Axes: >

# %%
fig, ax = plt.subplots(figsize=(7, 7))

counts = df['TIPOTRANSPORTE'].value_counts()
threshold = 0.03 # definir el umbral para agrupar valores en 'Otros'

# agrupar valores en 'Otros' si la frecuencia es menor que el umbral
mask = counts / counts.sum() < threshold
other = counts[mask].sum()
counts = counts[~mask]
counts['Otros'] = other

# plotear el gráfico de pastel
counts.plot(kind='pie', ax=ax, autopct='%1.1f%%', startangle=90, legend=True, labels=None)

# agregar los nombres de las categorías en el centro del gráfico
ax.set_title('Distribución de TIPOTRANSPORTE')
ax.legend(labels=counts.index, loc='upper left', bbox_to_anchor=(1, 0.5))

plt.show()

# %% [markdown]
# La mayoría de las plataformas de transporte que se usan son de 3 ejes neumática.

# %%
df.TIPO_PRODUCTO.value_counts().plot(kind="bar",alpha=0.5)
# Out:
# <Axes: >

# %%
fig, ax = plt.subplots(figsize=(6, 6))

counts = df['TIPO_PRODUCTO'].value_counts()
threshold = 0.02 # definir el umbral para agrupar valores en 'Otros'

# agrupar valores en 'Otros' si la frecuencia es menor que el umbral
mask = counts / counts.sum() < threshold
other = counts[mask].sum()
counts = counts[~mask]
counts['Otros'] = other

# plotear el gráfico de pastel
counts.plot(kind='pie', ax=ax, autopct='%1.1f%%', startangle=90, legend=True, labels=None)

# agregar los nombres de las categorías en el centro del gráfico
ax.set_title('Distribución de TIPO_PRODUCTO')
ax.legend(labels=counts.index, loc='upper left', bbox_to_anchor=(1, 0.5))

plt.show()

# %% [markdown]
# El producto más transportado son los rollos.

# %%
df.TIPO_FORMA.value_counts().plot(kind="bar",alpha=0.5)
# Out:
# <Axes: >

# %%
fig, ax = plt.subplots(figsize=(4, 4))

counts = df['TIPO_FORMA'].value_counts()
threshold = 0.015 # definir el umbral para agrupar valores en 'Otros'

# agrupar valores en 'Otros' si la frecuencia es menor que el umbral
mask = counts / counts.sum() < threshold
other = counts[mask].sum()
counts = counts[~mask]
counts['Otros'] = other

# plotear el gráfico de pastel
counts.plot(kind='pie', ax=ax, autopct='%1.1f%%', startangle=90, legend=True, labels=None)

# agregar los nombres de las categorías en el centro del gráfico
ax.set_title('Distribución de TIPO_FORMA')
ax.legend(labels=counts.index, loc='upper left', bbox_to_anchor=(1, 0.5))

plt.show()

# %% [markdown]
# Casi todas las formas que se transportan corresponden a la categoría de Planos.

# %%
df.TIPO_ASIGNACION.value_counts().plot(kind="bar",alpha=0.5)
# Out:
# <Axes: >

# %%
df.TIPO_ASIGNACION.value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='TIPO_ASIGNACION'>

# %% [markdown]
# La mayoría de las asignaciones son hechas de forma manual.

# %%
df.TIPO_PERMISO.value_counts().plot(kind="bar",alpha=0.5)
# Out:
# <Axes: >

# %%
df.TIPO_PERMISO.value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='TIPO_PERMISO'>

# %% [markdown]
# Cliente ENVIA y Traslado Externo son los permisos principales.

# %%
df.ZONA_DESTINO.value_counts().plot(kind="bar",alpha=0.5)
# Out:
# <Axes: >

# %%
fig, ax = plt.subplots(figsize=(4, 4))

counts = df['ZONA_DESTINO'].value_counts()
threshold = 0.02 # definir el umbral para agrupar valores en 'Otros'

# agrupar valores en 'Otros' si la frecuencia es menor que el umbral
mask = counts / counts.sum() < threshold
other = counts[mask].sum()
counts = counts[~mask]
counts['Otros'] = other

# plotear el gráfico de pastel
counts.plot(kind='pie', ax=ax, autopct='%1.1f%%', startangle=90, legend=True, labels=None)

# agregar los nombres de las categorías en el centro del gráfico
ax.set_title('Distribución de ZONA_DESTINO')
ax.legend(labels=counts.index, loc='upper left', bbox_to_anchor=(1, 0.5))

plt.show()

# %% [markdown]
# La mayoría de los valores de esta variable son 0, es decir, nulos

# %%
n = 15
top_n = df['CUIDAD'].value_counts().nlargest(n)
top_n.plot(kind='bar', alpha=0.5)
# Out:
# <Axes: >

# %%
fig, ax = plt.subplots(figsize=(4, 4))

counts = df['CUIDAD'].value_counts()
threshold = 0.04 # definir el umbral para agrupar valores en 'Otros'

# agrupar valores en 'Otros' si la frecuencia es menor que el umbral
mask = counts / counts.sum() < threshold
other = counts[mask].sum()
counts = counts[~mask]
counts['Otros'] = other

# plotear el gráfico de pastel
counts.plot(kind='pie', ax=ax, autopct='%1.1f%%', startangle=90, legend=True, labels=None)

# agregar los nombres de las categorías en el centro del gráfico
ax.set_title('Distribución de CUIDAD')
ax.legend(labels=counts.index, loc='upper left', bbox_to_anchor=(1, 0.5))

plt.show()

# %% [markdown]
# La mayoría de ciudades a las que se viajan están en Nuevo León.

# %%
import datetime

# convertir la columna fecha_hora en formato de fecha y hora
df['FECHAVIAJE'] = pd.to_datetime(df['FECHAVIAJE'])

# agregar una columna con la fecha (sin la hora)
df['FECHA'] = df['FECHAVIAJE'].dt.date
df['FECHA'].replace(datetime.date(2029, 11, 11), datetime.date(2022, 11, 11), inplace=True)

# contar la cantidad de viajes por día
viajes_por_dia = df.groupby('FECHA').size().reset_index(name='count')

# %%
plt.plot(viajes_por_dia['FECHA'], viajes_por_dia['count'])
plt.xlabel('Fecha')
plt.ylabel('Cantidad de viajes')
plt.title('Cantidad de viajes por día')
plt.show()

# %% [markdown]
# Podemos observar como cada mes tiene sus picos, esto quiere decir que hay días en los que hay cerca de 0 viajes, mientras que en el mismo periodo hayotros días con alrededor de 400 viajes al día.

# %%
fechas = ['FECHADESPACHO', 'FECHAVIAJE',
          'F_PRESENTACION', 'F_LLEGADANAVE',
          'F_EGRESONAVE', 'F_INGRESOPLANTA', 'F_PESAJEENTRADA', 'F_ASIGVIAJE',
          'F_INICIOCARGABULTO', 'F_FINCARGA', 'F_PESAJESALIDA']

# %%
df[fechas].dtypes
# Out:
# FECHADESPACHO                 object
# FECHAVIAJE            datetime64[ns]
# F_PRESENTACION                object
# F_LLEGADANAVE                 object
# F_EGRESONAVE                  object
# F_INGRESOPLANTA               object
# F_PESAJEENTRADA               object
# F_ASIGVIAJE                   object
# F_INICIOCARGABULTO            object
# F_FINCARGA                    object
# F_PESAJESALIDA                object
# dtype: object

# %%
for fecha in fechas:
    df[fecha] = pd.to_datetime(df[fecha])

# %%
for fecha in fechas:
    df[fecha] = df[fecha].dt.strftime('%Y-%m-%d')

# %%
df[fechas].dtypes
# Out:
# FECHADESPACHO         object
# FECHAVIAJE            object
# F_PRESENTACION        object
# F_LLEGADANAVE         object
# F_EGRESONAVE          object
# F_INGRESOPLANTA       object
# F_PESAJEENTRADA       object
# F_ASIGVIAJE           object
# F_INICIOCARGABULTO    object
# F_FINCARGA            object
# F_PESAJESALIDA        object
# dtype: object

# %%
fig, ax = plt.subplots(figsize=(4, 4))

counts = df['FECHADESPACHO'].value_counts()
threshold = 0.025 # definir el umbral para agrupar valores en 'Otros'

# agrupar valores en 'Otros' si la frecuencia es menor que el umbral
mask = counts / counts.sum() < threshold
other = counts[mask].sum()
counts = counts[~mask]
counts['Otros'] = other

# plotear el gráfico de pastel
counts.plot(kind='pie', ax=ax, autopct='%1.1f%%', startangle=90, legend=True, labels=None, fontsize=4)

# agregar los nombres de las categorías en el centro del gráfico
ax.set_title('Distribución de FECHADESPACHO')
ax.legend(labels=counts.index, loc='upper left', bbox_to_anchor=(1, 0.5))

plt.show()

# %%
fig, ax = plt.subplots(figsize=(4, 4))

counts = df['FECHAVIAJE'].value_counts()
threshold = 0.025 # definir el umbral para agrupar valores en 'Otros'

# agrupar valores en 'Otros' si la frecuencia es menor que el umbral
mask = counts / counts.sum() < threshold
other = counts[mask].sum()
counts = counts[~mask]
counts['Otros'] = other

# plotear el gráfico de pastel
counts.plot(kind='pie', ax=ax, autopct='%1.1f%%', startangle=90, legend=True, labels=None, fontsize=4)

# agregar los nombres de las categorías en el centro del gráfico
ax.set_title('Distribución de FECHAVIAJE')
ax.legend(labels=counts.index, loc='upper left', bbox_to_anchor=(1, 0.5))

plt.show()

# %%
fig, ax = plt.subplots(figsize=(4, 4))

counts = df['F_PESAJESALIDA'].value_counts()
threshold = 0.025 # definir el umbral para agrupar valores en 'Otros'

# agrupar valores en 'Otros' si la frecuencia es menor que el umbral
mask = counts / counts.sum() < threshold
other = counts[mask].sum()
counts = counts[~mask]
counts['Otros'] = other

# plotear el gráfico de pastel
counts.plot(kind='pie', ax=ax, autopct='%1.1f%%', startangle=90, legend=True, labels=None, fontsize=4)

# agregar los nombres de las categorías en el centro del gráfico
ax.set_title('Distribución de F_PESAJESALIDA')
ax.legend(labels=counts.index, loc='upper left', bbox_to_anchor=(1, 0.5))

plt.show()

# %% [markdown]
# Podemos observar que a pesar de que deberían tener los mismo registros, en algunos casos varáin, puede ser que sea porque en algunos casos el tiempo de espera y de carga es bastante que el proceso continúa en otro día, o que hay registros nulos difernetes en cada variable.
